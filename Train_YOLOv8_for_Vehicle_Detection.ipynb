# %% [markdown]
# <a href="https://colab.research.google.com/github/AsadBukhari886/yolov8-vehicle-detection/blob/main/Train_YOLOv8_for_Vehicle_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fine-Tuning YOLOv8 for Vehicle Detection
#
# This Colab notebook demonstrates how to train and fine-tune a YOLOv8 model on a custom vehicle detection dataset using Ultralytics YOLOv8 and Roboflow.
#
# # Overview
#
# In this notebook, you will:
#
# *   Install and set up YOLOv8 from Ultralytics.
#
# * Download a custom vehicle dataset from Roboflow.
#
# * Load a pretrained YOLOv8 model (YOLOv8n).
#
# * Fine-tune the model on the vehicle dataset.
#
# * Visualize training results and performance metrics.
#
# * Download the best-trained weights for deployment or inference.
#
# # Goal
#
# By the end of this notebook, you’ll have a custom-trained YOLOv8 model capable of detecting different types of vehicles with high accuracy.

# %% [markdown]
# # Install YOLOv8

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 46.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Import YOLO

# %%
from ultralytics import YOLO

#Check version
# !yolo version
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# 8.3.223

# %% [markdown]
# # Download Dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="9uFLN960L7sdBpKjwaL4")
project = rf.workspace("coconut-a8mio").project("vehicles-ldbmq")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 13.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 30.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 24.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Vehicles-2 in yolov8:: 100%|██████████| 77/77 [00:00<00:00, 8038.87it/s]

# %% [markdown]
# # Load a Pretrained YOLOv8 Model

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt") # pretrained model

# %% [markdown]
# # Fine-Tune the Model

# %%
model.train(
    data="/content/Vehicles-2/data.yaml",
    epochs=50,
    imgsz=640,                             # image size
)
# Out:
# Ultralytics 8.3.223 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# # Insights

# %%
from IPython.display import Image
Image("/content/runs/detect/train/results.png")

# %% [markdown]
# # Download

# %%
from google.colab import files
files.download('/content/runs/detect/train/weights/best.pt')
